# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-572c9511-1b49-4a95-9463-2165565401c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-572c9511-1b49-4a95-9463-2165565401c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['ESPN.csv']))
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s
# 0  54.04   51  68  14  2058  69
# 1  58.72   41  62  17  1509  73
# 2  45.97   45  58  16  1488  97
# 3  42.51   36  63   8  1654  21
# 4  46.95   33  57   9  1442  11

# %%
 df[["From","To"]] = df["Span"].str.split("-", expand=True)

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s  From    To
# 0  54.04   51  68  14  2058  69  1989  2013
# 1  58.72   41  62  17  1509  73  1995  2012
# 2  45.97   45  58  16  1488  97  1995  2013
# 3  42.51   36  63   8  1654  21  1996  2012
# 4  46.95   33  57   9  1442  11  2006  2018

# %%
 df[["Player name","Country"]] = df["Player"].str.split("(", expand=True)

# %%
print(df.to_string())
# Out:
#                        Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF     SR  100  50   0    4s   6s  From    To   Country         -                  Player name
# 0          SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437  54.04   51  68  14  2058   69  1989  2013      IND)      IND)      IND)      SR Tendulkar
# 1            RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782  58.72   41  62  17  1509   73  1995  2012      AUS)      AUS)      AUS)        RT Ponting
# 2          JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903  45.97   45  58  16  1488   97  1995  2013   ICC/SA)   ICC/SA)   ICC/SA)         JH Kallis
# 3          R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258  42.51   36  63   8  1654   21  1996  2012  ICC/IND)  ICC/IND)  ICC/IND)          R Dravid
# ...

# %%
df[["Country 1","Country 2"]] = df["Country"].str.split("/", expand=True)

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  ...    4s  6s  From    To   Country         -            \
# 0  54.04  ...  2058  69  1989  2013      IND)      IND)      IND)
# 1  58.72  ...  1509  73  1995  2012      AUS)      AUS)      AUS)
# 2  45.97  ...  1488  97  1995  2013   ICC/SA)   ICC/SA)   ICC/SA)
# 3  42.51  ...  1654  21  1996  2012  ICC/IND)  ICC/IND)  ICC/IND)
# 4  46.95  ...  1442  11  2006  2018      ENG)      ENG)      ENG)
#
#      Player name Country 2 Country 1
# 0  SR Tendulkar       None      IND)
# 1    RT Ponting       None      AUS)
# ...

# %%
import numpy as np

# %%
df["Consistency"] = np.where(df["HS"].str.contains(r"\*"),"Not Out","Out")

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  ...  6s  From    To   Country         -              Player name  \
# 0  54.04  ...  69  1989  2013      IND)      IND)      IND)  SR Tendulkar
# 1  58.72  ...  73  1995  2012      AUS)      AUS)      AUS)    RT Ponting
# 2  45.97  ...  97  1995  2013   ICC/SA)   ICC/SA)   ICC/SA)     JH Kallis
# 3  42.51  ...  21  1996  2012  ICC/IND)  ICC/IND)  ICC/IND)      R Dravid
# 4  46.95  ...  11  2006  2018      ENG)      ENG)      ENG)       AN Cook
#
#   Country 2 Country 1 Consistency
# ...
